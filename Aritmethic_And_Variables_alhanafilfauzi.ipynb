# %% [markdown]
# # Intro to Programming

# %% [markdown]
# Get Started with Python

# %% [markdown]
# ## Aritmetika dan Variabel
# Membuat perhitungan, dan mendefinisikan serta memodifikasi variabel.

# %% [markdown]
# Selamat datang di kursus Pengantar Pemrograman! Kursus ini cocok untuk Anda jika Anda belum pernah menulis satu baris kode pun, dan Anda tertarik untuk mempelajari ilmu data dan pembelajaran mesin.
# Dalam kursus ini, Anda akan belajar cara menggunakan kode untuk membuat komputer melakukan tugas-tugas tertentu untuk Anda. Python adalah salah satu bahasa pemrograman yang paling populer untuk ilmu data, dan itu adalah bahasa yang akan Anda pelajari dalam kursus ini.

# %% [markdown]
# ## Mencetak (Printing)
#
# Salah satu tugas paling sederhana (dan paling penting!) yang dapat Anda minta kepada komputer adalah mencetak pesan.
# Dalam Python, kita meminta komputer untuk mencetak pesan untuk kita dengan menulis print() dan meletakkan pesan di dalam tanda kurung dan diapit oleh tanda petik. Di bawah ini, kita meminta komputer untuk mencetak pesan Hello, world!.

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# Kode berada di dalam kotak (dikenal sebagai **cell code**), dan respons komputer (disebut **output** kode) ditampilkan di bawah kotak.

# %% [markdown]
# ### Aritmetika (Arithmetic)
# Kita juga dapat mencetak nilai dari beberapa operasi aritmatika (seperti penambahan, pengurangan, perkalian, atau pembagian).
# Misalnya, di sel kode berikutnya, komputer menambahkan 2 ke 1 dan kemudian mencetak hasilnya, yaitu 3. Perhatikan bahwa tidak seperti saat kita hanya mencetak teks, kita tidak menggunakan tanda petik apa pun.

# %%
print(1 + 2)
# Out:
# 3

# %% [markdown]
# Kita juga dapat melakukan pengurangan dalam python. Misalnya 9 dikurang 5 maka hasil yang tercetak adalah 4. Seperti kode dibawah ini.

# %%
print(9 - 5)
# Out:
# 4

# %% [markdown]
# Anda sebenarnya dapat melakukan banyak perhitungan dengan python! Lihat tabel di bawah ini untuk beberapa contoh.

# %%
import pandas as pd
df_tabel = pd.DataFrame(
        {"Operasi": ["Penjumlahan","Pengurangan","Perkalian","Pembagian","Kuadrat"],
         "Simbol" : ["+","-","*","/","**"],
         "Contoh" : ["1 + 2 = 3","5 - 4 = 1","2 * 4 = 8","6 / 3 = 2","3 ** 2 = 9"]
        }
)
df_tabel
# Out:
#        Operasi Simbol      Contoh
# 0  Penjumlahan      +   1 + 2 = 3
# 1  Pengurangan      -   5 - 4 = 1
# 2    Perkalian      *   2 * 4 = 8
# 3    Pembagian      /   6 / 3 = 2
# 4      Kuadrat     **  3 ** 2 = 9

# %% [markdown]
# Anda dapat mengontrol urutan operasi dalam perhitungan panjang dengan tanda kurung.

# %%
print(((1 + 3) * (9 - 2) / 2) ** 2)
# Out:
# 196.0

# %% [markdown]
# ### Komentar (Comments)
# Kita menggunakan komentar untuk memberi keterangan tentang apa yang dilakukan kode. Komentar membantu orang lain untuk memahami kode Anda, dan komentar juga dapat membantu jika Anda sudah lama tidak melihat kode Anda sendiri. Sejauh ini, kode yang kita tulis sangat pendek, tetapi anotasi menjadi lebih penting ketika Anda telah menulis banyak kode.
# Sebagai contoh, pada **cell code** berikutnya, kita mengalikan 3 dengan 2. Kita juga menambahkan komentar(**#Kalikan 3 dengan 2**) di atas kode untuk menjelaskan apa yang dilakukan kode tersebut.

# %%
#Kalikan 3 dengan 2
print(3 * 2)
# Out:
# 6

# %% [markdown]
# Perlu untuk diperhatikan penambahan tanda **#** di depan kode akan menjadikannya sebagai komentar yang nantinya tidak akan di eksekusi oleh program. Dan bagaimana jadinya jika tanda # tidak digunakan dalam membuat komentar? Perhatikan kode dibawah ini!

# %%
Kalikan 3 dengan 2
# Out:
#   Cell In[11], line 1
#     Kalikan 3 dengan 2
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# Kode di atas adalah contoh jika terjadi kesalahan sintaks pada Python

# %% [markdown]
# ### Variabel (Variables)
# Sejauh ini, Anda telah menggunakan kode untuk membuat kalkulasi dan mencetak hasilnya, dan hasilnya tidak disimpan di mana pun. Namun, Anda dapat membayangkan bahwa Anda mungkin ingin menyimpan hasilnya untuk digunakan nanti. Untuk itu, Anda perlu menggunakan **variabel**.

# %% [markdown]
# ### Membuat Variabel
# **Cell code** berikutnya membuat variabel bernama **test_var** dan memberikannya nilai yang kita dapatkan ketika kita menambahkan 5 ke 4.
# Kita kemudian mencetak nilai yang ditetapkan ke variabel tersebut, yaitu 9.

# %%
# Membuat sebuah variabel dengan nama test_var dan berikan nilai 4+5
test_var = 4 + 5

# Cetak nilai dari variabel test_var
print(test_var)
# Out:
# 9

# %% [markdown]
# Secara umum, sebelum menentukan nama variabel, Anda harus mulai dengan memilih nama yang ingin Anda gunakan. Nama variabel idealnya pendek dan deskriptif. Mereka juga harus memenuhi beberapa persyaratan:
#
# 1. Tidak boleh ada spasi (misalnya, **test var** tidak diperbolehkan)
# 2. Mereka hanya boleh menyertakan huruf, angka, dan garis bawah (misalnya, **test_var!** tidak diperbolehkan)
# 3. Nama variabel harus dimulai dengan huruf atau garis bawah (misalnya, **1_var** tidak diperbolehkan)
#
# Kemudian, untuk membuat variabel, Anda perlu menggunakan **=** untuk menetapkan nilai yang Anda inginkan.
# Anda selalu dapat melihat nilai yang ditetapkan ke variabel dengan menggunakan **print()** dan meletakkan nama variabel dalam tanda kurung.
# Seiring berjalannya waktu, Anda akan belajar bagaimana memilih nama yang baik untuk variabel Python. Tidak masalah jika sekarang terasa tidak nyaman, dan cara terbaik untuk belajar adalah dengan melihat banyak kode Python!

# %% [markdown]
# ### Mengolah Variabel
# Anda selalu dapat mengubah nilai yang ditetapkan ke variabel dengan menimpa nilai sebelumnya Pada sel kode di bawah ini, kami mengubah nilai **my_var** dari 3 menjadi 100.

# %%
# Menetapkan nilai variabel my_var dengan 3
my_var = 3

# Mencetak nilai yang sudah ditetapkan
print(my_var)

# Mengganti nilai variabel my_var menjadi 100
my_var = 100

# Mencetak Nilai yang sudah diubah
print(my_var)
# Out:
# 3
# 100

# %% [markdown]
# Perhatikan bahwa secara umum, setiap kali Anda mendefinisikan variabel dalam sel kode, semua sel kode berikutnya juga memiliki akses ke variabel tersebut. Sebagai contoh, kita menggunakan sel kode berikutnya untuk mengakses nilai **my_var** (dari **cell code** di atas) dan **test_var**

# %%
print(my_var)
print(test_var)
# Out:
# 100
# 9

# %% [markdown]
# **Cell code** berikutnya memberitahu Python untuk meningkatkan nilai **my_var** saat ini sebesar 3.
# Untuk melakukan ini, kita masih perlu menggunakan **my_var =** seperti sebelumnya. Dan juga seperti sebelumnya, nilai baru yang ingin kita tetapkan ke variabel berada di sebelah kanan tanda** =.**

# %%
# Tambahkan nilai dengan 3
my_var = my_var + 3

# Cetak nilai setelah ditambahkan
print(my_var)
# Out:
# 103

# %% [markdown]
# ### Menggunakan Beberapa Variabel
# Adalah hal yang umum bagi kode untuk menggunakan banyak variabel. Hal ini sangat berguna ketika kita harus melakukan perhitungan yang panjang dengan beberapa input.
# Pada **cell code** berikutnya, kita menghitung jumlah detik dalam empat tahun. Perhitungan ini menggunakan lima input.

# %%
# Membuat Variabel
num_years = 4
days_per_year = 365 
hours_per_day = 24
mins_per_hour = 60
secs_per_min = 60

# Hitung jumlah detik
total_secs = secs_per_min * mins_per_hour * hours_per_day * days_per_year * num_years
print(total_secs)
# Out:
# 126144000

# %% [markdown]
# Seperti yang dihitung di atas, ada **126144000 detik** dalam empat tahun.
# Perlu dicatat bahwa perhitungan ini dapat dilakukan tanpa variabel hanya dengan **60 * 60 * 24 * 365 * 4**, namun akan jauh lebih sulit untuk memeriksa bahwa perhitungan tanpa variabel tidak memiliki kesalahan, karena tidak mudah dibaca. Ketika kita menggunakan variabel (seperti **num_years, days_per_year**, dll), kita dapat melacak setiap bagian dari kalkulasi dengan lebih baik dan lebih mudah untuk memeriksa dan memperbaiki kesalahan.
# Perhatikan bahwa sangat berguna untuk menggunakan variabel ketika nilai dari input dapat berubah. Sebagai contoh, katakanlah kita ingin sedikit meningkatkan perkiraan kita dengan memperbarui nilai jumlah hari dalam setahun dari 365 menjadi 365,25, untuk memperhitungkan tahun kabisat. Kemudian kita bisa mengubah nilai yang diberikan ke **days_per_year** tanpa mengubah variabel lainnya dan mengulang perhitungan.

# %%
# Perbaharui
days_per_year = 365.25

# Hitung jumlah detik dalam 4 tahun
total_secs = secs_per_min * mins_per_hour * hours_per_day * days_per_year * num_years
print(total_secs)
# Out:
# 126230400.0

# %% [markdown]
# **Catatan:** Anda mungkin telah memperhatikan angka .0 yang ditambahkan di akhir angka, yang mungkin terlihat tidak perlu. Hal ini disebabkan oleh fakta bahwa pada perhitungan kedua, kami menggunakan angka dengan bagian pecahan (365,25), sedangkan perhitungan pertama hanya mengalikan angka tanpa bagian pecahan.

# %% [markdown]
# ## Debugging
# Salah satu kesalahan umum saat bekerja dengan variabel adalah kesalahan pengetikan yang tidak disengaja. Sebagai contoh, jika kita mengeja hours_per_day as hours_per_dy, Python akan membuat kesalahan dengan pesan NameError: name 'hours_per_dy' is not defined.

# %%
print(hours_per_dy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(hours_per_dy)
#
# NameError: name 'hours_per_dy' is not defined

# %% [markdown]
# Jika muncul hal seperti ini, cobalah untuk memperbaiki pengejaanya.

# %%
print(hours_per_day)
# Out:
# 24
